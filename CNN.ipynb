# %% [markdown]
# https://github.com/Azure/DeepLearningForTimeSeriesForecasting/blob/master/1_CNN_dilated.ipynb

# %%
import os
import warnings
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime as dt
from collections import UserDict
from glob import glob
from IPython.display import Image
# %matplotlib inline

from common.utils import load_data, mape

pd.options.display.float_format = '{:,.2f}'.format
np.set_printoptions(precision=2)
warnings.filterwarnings("ignore")

# %%
data_dir = 'C:/Users/diana/Desktop/proiect test/energy_client/'
energy = load_data(data_dir)[['load']]
energy.head()
# Out:
#                      load
# 2023-05-15 00:15:00  0.13
# 2023-05-15 00:30:00  0.13
# 2023-05-15 00:45:00  0.13
# 2023-05-15 01:00:00  0.11
# 2023-05-15 01:15:00  0.10

# %%
valid_start_dt = '2023-05-19 05:00:00'
test_start_dt = '2023-05-20 14:30:00'

# %%
energy[energy.index < valid_start_dt][['load']].rename(columns={'load':'train'}) \
    .join(energy[(energy.index >=valid_start_dt) & (energy.index < test_start_dt)][['load']] \
          .rename(columns={'load':'validation'}), how='outer') \
    .join(energy[test_start_dt:][['load']].rename(columns={'load':'test'}), how='outer') \
    .plot(y=['train', 'validation', 'test'], figsize=(15, 8), fontsize=12)
plt.xlabel('timestamp', fontsize=12)
plt.ylabel('load', fontsize=12)
plt.show()

# %%
T = 10
HORIZON = 1

# %%
train = energy.copy()[energy.index < valid_start_dt][['load']]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
train['load'] = scaler.fit_transform(train)
train.head(10)
# Out:
#                      load
# 2023-05-15 00:15:00  0.19
# 2023-05-15 00:30:00  0.19
# 2023-05-15 00:45:00  0.19
# 2023-05-15 01:00:00  0.17
# 2023-05-15 01:15:00  0.15
# 2023-05-15 01:30:00  0.16
# 2023-05-15 01:45:00  0.14
# 2023-05-15 02:00:00  0.13
# 2023-05-15 02:15:00  0.10
# 2023-05-15 02:30:00  0.15

# %%
energy[energy.index < valid_start_dt][['load']].rename(columns={'load':'original load'}).plot.hist(bins=100, fontsize=12)
train.rename(columns={'load':'scaled load'}).plot.hist(bins=100, fontsize=12)
plt.show()

# %%
train_shifted = train.copy()
train_shifted['y_t+1'] = train_shifted['load'].shift(-1, freq='H')
train_shifted.head(10)
# Out:
#                      load  y_t+1
# 2023-05-15 00:15:00  0.19   0.15
# 2023-05-15 00:30:00  0.19   0.16
# 2023-05-15 00:45:00  0.19   0.14
# 2023-05-15 01:00:00  0.17   0.13
# 2023-05-15 01:15:00  0.15   0.10
# 2023-05-15 01:30:00  0.16   0.15
# 2023-05-15 01:45:00  0.14   0.17
# 2023-05-15 02:00:00  0.13   0.14
# 2023-05-15 02:15:00  0.10   0.15
# 2023-05-15 02:30:00  0.15   0.16

# %%
for t in range(1, T+1):
    train_shifted['load_t-'+str(T-t)] = train_shifted['load'].shift(T-t, freq='H')
train_shifted = train_shifted.rename(columns={'load':'load_original'})
train_shifted.head(10)
# Out:
#                      load_original  y_t+1  load_t-9  load_t-8  load_t-7
# 2023-05-15 00:15:00           0.19   0.15       NaN       NaN       NaN  \
# 2023-05-15 00:30:00           0.19   0.16       NaN       NaN       NaN
# 2023-05-15 00:45:00           0.19   0.14       NaN       NaN       NaN
# 2023-05-15 01:00:00           0.17   0.13       NaN       NaN       NaN
# 2023-05-15 01:15:00           0.15   0.10       NaN       NaN       NaN
# 2023-05-15 01:30:00           0.16   0.15       NaN       NaN       NaN
# 2023-05-15 01:45:00           0.14   0.17       NaN       NaN       NaN
# 2023-05-15 02:00:00           0.13   0.14       NaN       NaN       NaN
# 2023-05-15 02:15:00           0.10   0.15       NaN       NaN       NaN
# 2023-05-15 02:30:00           0.15   0.16       NaN       NaN       NaN
#
#                      load_t-6  load_t-5  load_t-4  load_t-3  load_t-2
# 2023-05-15 00:15:00       NaN       NaN       NaN       NaN       NaN  \
# 2023-05-15 00:30:00       NaN       NaN       NaN       NaN       NaN
# 2023-05-15 00:45:00       NaN       NaN       NaN       NaN       NaN
# 2023-05-15 01:00:00       NaN       NaN       NaN       NaN       NaN
# 2023-05-15 01:15:00       NaN       NaN       NaN       NaN       NaN
# 2023-05-15 01:30:00       NaN       NaN       NaN       NaN       NaN
# 2023-05-15 01:45:00       NaN       NaN       NaN       NaN       NaN
# 2023-05-15 02:00:00       NaN       NaN       NaN       NaN       NaN
# 2023-05-15 02:15:00       NaN       NaN       NaN       NaN      0.19
# 2023-05-15 02:30:00       NaN       NaN       NaN       NaN      0.19
#
#                      load_t-1  load_t-0
# 2023-05-15 00:15:00       NaN      0.19
# 2023-05-15 00:30:00       NaN      0.19
# 2023-05-15 00:45:00       NaN      0.19
# 2023-05-15 01:00:00       NaN      0.17
# 2023-05-15 01:15:00      0.19      0.15
# 2023-05-15 01:30:00      0.19      0.16
# 2023-05-15 01:45:00      0.19      0.14
# 2023-05-15 02:00:00      0.17      0.13
# 2023-05-15 02:15:00      0.15      0.10
# 2023-05-15 02:30:00      0.16      0.15

# %%
train_shifted = train_shifted.dropna(how='any')
train_shifted.head(5)
# Out:
#                      load_original  y_t+1  load_t-9  load_t-8  load_t-7
# 2023-05-15 09:15:00           0.11   0.00      0.19      0.15      0.10  \
# 2023-05-15 09:30:00           0.00   0.00      0.19      0.16      0.15
# 2023-05-15 09:45:00           0.00   0.00      0.19      0.14      0.17
# 2023-05-15 10:00:00           0.00   0.08      0.17      0.13      0.14
# 2023-05-15 10:15:00           0.00   0.49      0.15      0.10      0.15
#
#                      load_t-6  load_t-5  load_t-4  load_t-3  load_t-2
# 2023-05-15 09:15:00      0.15      0.11      0.10      0.14      0.04  \
# 2023-05-15 09:30:00      0.16      0.13      0.15      0.12      0.06
# 2023-05-15 09:45:00      0.18      0.14      0.16      0.14      0.11
# 2023-05-15 10:00:00      0.12      0.14      0.17      0.08      0.08
# 2023-05-15 10:15:00      0.11      0.10      0.14      0.04      0.12
#
#                      load_t-1  load_t-0
# 2023-05-15 09:15:00      0.12      0.11
# 2023-05-15 09:30:00      0.11      0.00
# 2023-05-15 09:45:00      0.13      0.00
# 2023-05-15 10:00:00      0.07      0.00
# 2023-05-15 10:15:00      0.11      0.00

# %%
y_train = train_shifted[['y_t+1']].to_numpy()

# %%
y_train.shape
# Out:
# (317, 1)

# %%
y_train[:3]
# Out:
# array([[0.],
#        [0.],
#        [0.]])

# %%
X_train = train_shifted[['load_t-'+str(T-t) for t in range(1, T+1)]].to_numpy()
X_train = X_train[... , np.newaxis]

# %%
X_train.shape
# Out:
# (317, 10, 1)

# %%
X_train[:3]
# Out:
# array([[[0.19],
#         [0.15],
#         [0.1 ],
#         [0.15],
#         [0.11],
#         [0.1 ],
#         [0.14],
#         [0.04],
#         [0.12],
#         [0.11]],
#
#        [[0.19],
#         [0.16],
#         [0.15],
#         [0.16],
#         [0.13],
#         [0.15],
#         [0.12],
#         [0.06],
#         [0.11],
#         [0.  ]],
#
#        [[0.19],
#         [0.14],
#         [0.17],
#         [0.18],
#         [0.14],
#         [0.16],
#         [0.14],
#         [0.11],
#         [0.13],
#         [0.  ]]])

# %%
train_shifted.head(3)
# Out:
#                      load_original  y_t+1  load_t-9  load_t-8  load_t-7
# 2023-05-15 09:15:00           0.11   0.00      0.19      0.15      0.10  \
# 2023-05-15 09:30:00           0.00   0.00      0.19      0.16      0.15
# 2023-05-15 09:45:00           0.00   0.00      0.19      0.14      0.17
#
#                      load_t-6  load_t-5  load_t-4  load_t-3  load_t-2
# 2023-05-15 09:15:00      0.15      0.11      0.10      0.14      0.04  \
# 2023-05-15 09:30:00      0.16      0.13      0.15      0.12      0.06
# 2023-05-15 09:45:00      0.18      0.14      0.16      0.14      0.11
#
#                      load_t-1  load_t-0
# 2023-05-15 09:15:00      0.12      0.11
# 2023-05-15 09:30:00      0.11      0.00
# 2023-05-15 09:45:00      0.13      0.00

# %%
look_back_dt = dt.datetime.strptime(valid_start_dt, '%Y-%m-%d %H:%M:%S') - dt.timedelta(hours=T-1)
valid = energy.copy()[(energy.index >=look_back_dt) & (energy.index < test_start_dt)][['load']]
valid.head()
# Out:
#                      load
# 2023-05-18 20:00:00  0.09
# 2023-05-18 20:15:00  0.14
# 2023-05-18 20:30:00  0.19
# 2023-05-18 20:45:00  0.19
# 2023-05-18 21:00:00  0.18

# %%
valid['load'] = scaler.transform(valid)
valid.head()
# Out:
#                      load
# 2023-05-18 20:00:00  0.14
# 2023-05-18 20:15:00  0.21
# 2023-05-18 20:30:00  0.28
# 2023-05-18 20:45:00  0.28
# 2023-05-18 21:00:00  0.27

# %%
valid_shifted = valid.copy()
valid_shifted['y+1'] = valid_shifted['load'].shift(-1, freq='H')
for t in range(1, T+1):
    valid_shifted['load_t-'+str(T-t)] = valid_shifted['load'].shift(T-t, freq='H')
valid_shifted = valid_shifted.dropna(how='any')
y_valid = valid_shifted['y+1'].to_numpy()
X_valid = valid_shifted[['load_t-'+str(T-t) for t in range(1, T+1)]].to_numpy()
X_valid = X_valid[..., np.newaxis]

# %%
y_valid.shape
# Out:
# (130,)

# %%
X_valid.shape
# Out:
# (130, 10, 1)

# %%
from keras.models import Model, Sequential
from keras.layers import Conv1D, Dense, Flatten
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
LATENT_DIM = 5
KERNEL_SIZE = 2
BATCH_SIZE = 32
EPOCHS = 10

# %%
model = Sequential()
model.add(Conv1D(LATENT_DIM, kernel_size=KERNEL_SIZE, padding='causal', strides=1, activation='relu', dilation_rate=1, input_shape=(T, 1)))
model.add(Conv1D(LATENT_DIM, kernel_size=KERNEL_SIZE, padding='causal', strides=1, activation='relu', dilation_rate=2))
model.add(Conv1D(LATENT_DIM, kernel_size=KERNEL_SIZE, padding='causal', strides=1, activation='relu', dilation_rate=4))
model.add(Flatten())
model.add(Dense(HORIZON, activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 10, 5)             15
#
#  conv1d_4 (Conv1D)           (None, 10, 5)             55
#
#  conv1d_5 (Conv1D)           (None, 10, 5)             55
#
#  flatten_1 (Flatten)         (None, 50)                0
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 176
# Trainable params: 176
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='Adam', loss='mse')

# %%
earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=5)

# %%
best_val = ModelCheckpoint('model_{epoch:02d}.h5', save_best_only=True, mode='min', period=1)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(X_train,
          y_train,
          batch_size=BATCH_SIZE,
          epochs=EPOCHS,
          validation_data=(X_valid, y_valid),
          callbacks=[earlystop, best_val],
          verbose=1)
# Out:
# Epoch 1/10
# 10/10 [==============================] - 2s 30ms/step - loss: 0.0626 - val_loss: 0.1163
# Epoch 2/10
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0499 - val_loss: 0.1011
# Epoch 3/10
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0388 - val_loss: 0.0883
# Epoch 4/10
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0303 - val_loss: 0.0806
# Epoch 5/10
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0281 - val_loss: 0.0789
# Epoch 6/10
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0284 - val_loss: 0.0787
# Epoch 7/10
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0279 - val_loss: 0.0790
# Epoch 8/10
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0275 - val_loss: 0.0797
# Epoch 9/10
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0273 - val_loss: 0.0797
# Epoch 10/10
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0271 - val_loss: 0.0797

# %%
best_epoch = np.argmin(np.array(history.history['val_loss']))+1
model.load_weights("model_{:02d}.h5".format(best_epoch))

# %%
plot_df = pd.DataFrame.from_dict({'train_loss':history.history['loss'], 'val_loss':history.history['val_loss']})
plot_df.plot(logy=True, figsize=(10,10), fontsize=12)
plt.xlabel('epoch', fontsize=12)
plt.ylabel('loss', fontsize=12)
plt.show()

# %%
look_back_dt = dt.datetime.strptime(test_start_dt, '%Y-%m-%d %H:%M:%S') - dt.timedelta(hours=T-1)
test = energy.copy()[test_start_dt:][['load']]
test.head()
# Out:
#                      load
# 2023-05-20 14:30:00  0.00
# 2023-05-20 14:45:00  0.00
# 2023-05-20 15:00:00  0.00
# 2023-05-20 15:15:00  0.00
# 2023-05-20 15:30:00  0.00

# %%
test['load'] = scaler.transform(test)
test.head()
# Out:
#                      load
# 2023-05-20 14:30:00  0.00
# 2023-05-20 14:45:00  0.00
# 2023-05-20 15:00:00  0.00
# 2023-05-20 15:15:00  0.00
# 2023-05-20 15:30:00  0.00

# %%
test_shifted = test.copy()
test_shifted['y_t+1'] = test_shifted['load'].shift(-1, freq='H')
for t in range(1, T+1):
    test_shifted['load_t-'+str(T-t)] = test_shifted['load'].shift(T-t, freq='H')
test_shifted = test_shifted.dropna(how='any')
y_test = test_shifted['y_t+1'].to_numpy()
X_test = test_shifted[['load_t-'+str(T-t) for t in range(1, T+1)]].to_numpy()
X_test = X_test[... , np.newaxis]

# %%
predictions = model.predict(X_test)
predictions
# Out:
# 3/3 [==============================] - 0s 3ms/step
# array([[0.19],
#        [0.2 ],
#        [0.2 ],
#        [0.2 ],
#        [0.19],
#        [0.18],
#        [0.18],
#        [0.18],
#        [0.19],
#        [0.22],
#        [0.21],
#        [0.22],
#        [0.23],
#        [0.21],
#        [0.22],
#        [0.2 ],
#        [0.19],
#        [0.19],
#        [0.18],
#        [0.19],
#        [0.18],
#        [0.19],
#        [0.19],
#        [0.2 ],
#        [0.21],
#        [0.22],
#        [0.22],
#        [0.22],
#        [0.22],
#        [0.23],
#        [0.24],
#        [0.24],
#        [0.23],
#        [0.22],
#        [0.22],
#        [0.22],
#        [0.23],
#        [0.22],
#        [0.22],
#        [0.22],
#        [0.21],
#        [0.21],
#        [0.21],
#        [0.22],
#        [0.21],
#        [0.22],
#        [0.21],
#        [0.21],
#        [0.21],
#        [0.2 ],
#        [0.2 ],
#        [0.21],
#        [0.2 ],
#        [0.21],
#        [0.22],
#        [0.22],
#        [0.22],
#        [0.21],
#        [0.21],
#        [0.21],
#        [0.2 ],
#        [0.2 ],
#        [0.2 ],
#        [0.2 ],
#        [0.22],
#        [0.22],
#        [0.21],
#        [0.21],
#        [0.2 ],
#        [0.2 ],
#        [0.19],
#        [0.19],
#        [0.19],
#        [0.19],
#        [0.19],
#        [0.19],
#        [0.19],
#        [0.19],
#        [0.2 ],
#        [0.19],
#        [0.19],
#        [0.19],
#        [0.17],
#        [0.18],
#        [0.19],
#        [0.19],
#        [0.19],
#        [0.19],
#        [0.18],
#        [0.18],
#        [0.21],
#        [0.2 ],
#        [0.19],
#        [0.2 ],
#        [0.18]], dtype=float32)

# %%
eval_df = pd.DataFrame(predictions, columns=['t+'+str(t) for t in range(1, HORIZON+1)])
eval_df['timestamp'] = test_shifted.index
eval_df = pd.melt(eval_df, id_vars='timestamp', value_name='prediction', var_name='h')
eval_df['actual'] = np.transpose(y_test).ravel()
eval_df[['prediction', 'actual']] = scaler.inverse_transform(eval_df[['prediction', 'actual']])
eval_df.head()
# Out:
#             timestamp    h  prediction  actual
# 0 2023-05-20 23:30:00  t+1        0.13    0.16
# 1 2023-05-20 23:45:00  t+1        0.13    0.18
# 2 2023-05-21 00:00:00  t+1        0.13    0.16
# 3 2023-05-21 00:15:00  t+1        0.13    0.20
# 4 2023-05-21 00:30:00  t+1        0.13    0.19

# %%
mape(eval_df['prediction'], eval_df['actual'])
# Out:
# inf

# %%
eval_df[eval_df.timestamp<'2023-05-23'].plot(x='timestamp', y=['prediction', 'actual'], style=['r', 'b'], figsize=(15, 8))
plt.xlabel('timestamp', fontsize=12)
plt.ylabel('load', fontsize=12)
plt.show()

# %%
for m in glob('model_*.h5'):
    os.remove(m)
